# %% [markdown]
# # Data Visualization - Seaborn

# %% [markdown]
# # Load DataSet

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import seaborn as sns

# %%
iris = datasets.load_iris() 

df= pd.DataFrame(data= np.c_[iris['data'], iris['target']], 
                 columns= iris['feature_names'] + ['target'])
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# 3     0.0  setosa
# 4     0.0  setosa

# %% [markdown]
# ## 1. Pair Plot

# %%
# Pair plot works with neumerical data only:

sns.pairplot(df)

# %%
sns.pairplot(df, diag_kind="kde")

# %%
# Assign color accorting to categories - - which are not neumerical

sns.pairplot(df, hue="species")

# %%
sns.pairplot(df, diag_kind="hist", hue="species")

# %%
sns.pairplot(df, hue="species", palette="husl")

# %%
sns.pairplot(df, hue="species", markers=["o", "s", "d"])

# %%
#Regression:

sns.pairplot(df, kind="reg")

# %% [markdown]
# ## 2. Heatmap

# %%
#It defines the correlations: [-1, 0, 1]

corr_df = df[["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"]].corr(method="pearson")
sns.heatmap(corr_df, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr_df, annot=True, linewidth=2, linecolor="yellow")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr_df, annot=True, cmap="PiYG")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. Density Plot

# %%
# Only takes neumericals:

sns.kdeplot(df["sepal width (cm)"])
# Out:
# <AxesSubplot:xlabel='sepal width (cm)', ylabel='Density'>

# %%
sns.kdeplot(df["sepal width (cm)"], shade=True)
# Out:
# <AxesSubplot:xlabel='sepal width (cm)', ylabel='Density'>

# %%
sns.kdeplot(df["sepal width (cm)"], shade=True, color="yellow")
# Out:
# <AxesSubplot:xlabel='sepal width (cm)', ylabel='Density'>

# %%
sns.kdeplot(df["sepal width (cm)"], shade=True, vertical=True, color="skyblue")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Density', ylabel='sepal width (cm)'>

# %% [markdown]
# ## 4. Bar Plot

# %%
iris = datasets.load_iris() 

df= pd.DataFrame(data= np.c_[iris['data'], iris['target']], 
                 columns= iris['feature_names'] + ['target'])
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# 3     0.0  setosa
# 4     0.0  setosa

# %%
sns.barplot(x="species", y="sepal width (cm)", data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal width (cm)'>

# %%
sns.barplot(x="species", y="sepal length (cm)", data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal length (cm)'>

# %%
# The number of 'sepal length' for each species:


sns.barplot(x="species", y="petal width (cm)", data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal width (cm)'>

# %% [markdown]
# ## 5. Catplot

# %%
sns.catplot(x="species", y="sepal width (cm)", data=df)

# %%
sns.catplot(x="species", y="petal length (cm)", data=df)

# %%
# Can be box plot: Reprpesent both categorical/ neumerical data

sns.catplot(x="species", y="sepal width (cm)", kind="box", data=df)

# %%
sns.catplot(x="species", y="sepal width (cm)", kind="violin", data=df)

# %%
sns.catplot(x="species", y="sepal width (cm)", kind="violin", inner=None, data=df)

# %%
sns.catplot(y="sepal width (cm)", kind="count", palette="pastel", edgecolor="0.6", data=df)

# %%
#Shows the average#

sns.catplot(x="species", y="sepal width (cm)", kind="point", data=df)

# %% [markdown]
# ## 6. Factor Plot

# %%
iris = datasets.load_iris() 

df= pd.DataFrame(data= np.c_[iris['data'], iris['target']], 
                 columns= iris['feature_names'] + ['target'])
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# 3     0.0  setosa
# 4     0.0  setosa

# %%
g = sns.factorplot(x="sepal width (cm)",
                  y="sepal length (cm)",
                  data=df,
                  hue="species",
                  col="species",
                  kind="swarm")    #Swarmplot#
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
g = sns.factorplot(x="petal width (cm)",
                  y="petal length (cm)",
                  data=df,
                  hue="species",
                  col="species",
                  kind="swarm")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 41.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 7. Joint Distribution Plot

# %%
iris = datasets.load_iris() 

df= pd.DataFrame(data= np.c_[iris['data'], iris['target']], 
                 columns= iris['feature_names'] + ['target'])
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# 3     0.0  setosa
# 4     0.0  setosa

# %%
# Scatter and histogram together:

sns.jointplot(x="sepal width (cm)", y="sepal length (cm)", data=df)

# %%
sns.jointplot(x="petal width (cm)", y="petal length (cm)", data=df)

# %% [markdown]
# #### 7.1 Customization plot

# %%
sns.jointplot(x="sepal width (cm)", y="sepal length (cm)", kind="kde", data=df)

# %%
#Recognise how they are similer -- No need to joint usually#

(sns.jointplot(x="sepal width (cm)", y="sepal length (cm)", 
               data=df, color="k")
 .plot_joint(sns.kdeplot, zorder=0, n_levels=6))
